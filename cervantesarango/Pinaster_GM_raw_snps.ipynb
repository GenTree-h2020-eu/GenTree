# %%
import numpy as np
import scipy
import pandas
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('white')
sns.set_style('ticks')
sns.set_context('notebook')
import h5py
import allel; print('scikit-allel', allel.__version__)
# Out:
# scikit-allel 1.2.1

# %%
#allel.vcf_to_hdf5('/media/scervant/Transcend/GenTree_GM/Pinus_pinaster/Ppinaster_raw_SNPs.vcf', '/media/scervant/Transcend/GenTree_GM/Pinus_pinaster/Ppinaster_raw_SNPs.h5', fields='*', overwrite=True)

# %%
callset_fn = '/media/scervant/Transcend/GenTree_GM/Pinus_pinaster/Ppinaster_raw_SNPs.h5'
callset = h5py.File(callset_fn, mode='r')
callset
# Out:
# <HDF5 file "Ppinaster_raw_SNPs.h5" (mode r)>

# %%
sorted(callset.keys())
# Out:
# ['calldata', 'samples', 'variants']

# %%
variants = allel.VariantChunkedTable(callset['variants'], 
                                     names=['POS', 'REF', 'ALT','DP', 'QUAL', 'AN', 'MQ', 'QD', 'SOR', 'MQRankSum', 'ReadPosRankSum', 'numalt'])
variants
# Out:
# <VariantChunkedTable shape=(2297077,) dtype=[('POS', '<i4'), ('REF', 'O'), ('ALT', 'O', (3,)), ('DP', '<i4'), ('QUAL', '<f4'), ('AN', '<i4'), ('MQ', '<f4'), ('QD', '<f4'), ('SOR', '<f4'), ('MQRankSum', '<f4'), ('ReadPosRankSum', '<f4'), ('numalt', '<i4')]
#    nbytes=157.7M cbytes=61.1M cratio=2.6
#    values=h5py._hl.group.Group>

# %%
#callset['variants']
#list(variants)

# %%
callset['samples']
# Out:
# <HDF5 dataset "samples": shape (1080,), type "|O">

# %%
variants = callset['variants']
variants
# Out:
# <HDF5 group "/variants" (29 members)>

# %%
#list(variants)

# %%
#numalt = variants['numalt'][:]
#numalt
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
def plot_variant_hist(f, bins=30):
    x = variants[f][:]
    fig, ax = plt.subplots(figsize=(7, 5))
    sns.despine(ax=ax, offset=10)
    ax.hist(x, bins=bins)
    ax.set_xlabel(f)
    ax.set_ylabel('No. variants')
    ax.set_title('Variant %s distribution' % f)

# %%
plot_variant_hist('numalt', bins=np.arange(0.5, 5.5, 1))
plt.gca().set_xticks([1,2,3])
# Out:
# [<matplotlib.axis.XTick at 0x7f79f972fad0>,
#  <matplotlib.axis.XTick at 0x7f79f9668850>,
#  <matplotlib.axis.XTick at 0x7f7a03378910>]

# %%
plot_variant_hist('DP', bins=100)

# %%
plot_variant_hist('MQ', bins=100)
# Out:
# /wrk/Programs/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /wrk/Programs/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
MQ = variants['MQ'][:]
MQ
# Out:
# array([41.13, 39.93, 42.16, ..., 16.69, 13.5 , 11.65], dtype=float32)

# %%
plot_variant_hist('QD', bins=100)
plt.savefig('/wrk/Gen_Tree/GenTree_Genome_mapping/Pinus_pinaster/Ppinaster_GM_QD_distribution')
# Out:
# /wrk/Programs/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /wrk/Programs/miniconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plot_variant_hist('QUAL', bins=100)

# %%
plot_variant_hist('SOR')

# %%
plot_variant_hist('AN')
plt.savefig('/wrk/Gen_Tree/GenTree_Genome_mapping/Pinus_pinaster/Ppinaster_GM_AN_distribution')

# %%
plot_variant_hist('MQRankSum')

# %%
plot_variant_hist('ReadPosRankSum')

# %%
samples = callset['samples']
list(samples)
# Out:
# ['ARZ-29-01b5',
#  'ARZ-29-02b5',
#  'ARZ-29-04b5',
#  'ARZ-29-05b5',
#  'ARZ-29-06b5',
#  'ARZ-29-07b5',
#  'ARZ-29-08b5',
#  'ARZ-29-09b5',
#  'ARZ-29-11b5',
#  'ARZ-29-12b5',
#  'ARZ-29-13b5',
#  'ARZ-29-14b5',
#  'AUL-10-01b2',
#  'AUL-10-01b4',
#  'AUL-10-01b5',
#  'AUL-10-02b2',
#  'AUL-10-02b4',
#  'AUL-10-02b5',
#  'AUL-10-05b2',
#  'AUL-10-05b4',
#  'AUL-10-05b5',
#  'AUL-10-06b2',
#  'AUL-10-06b4',
#  'AUL-10-06b5',
#  'AUL-10-07b2',
#  'AUL-10-07b4',
#  'AUL-10-07b5',
#  'AUL-10-08b2',
#  'AUL-10-08b4',
#  'AUL-10-08b5',
#  'AUL-10-09b2',
#  'AUL-10-09b4',
#  'AUL-10-09b5',
#  'AUL-10-11b2',
#  'AUL-10-11b4',
#  'AUL-10-11b5',
#  'AUL-10-12b2',
#  'AUL-10-12b4',
#  'AUL-10-12b5',
#  'AUL-10-14b2',
#  'AUL-10-14b4',
#  'AUL-10-14b5',
#  'AUL-10-16b2',
#  'AUL-10-16b4',
#  'AUL-10-16b5',
#  'AUL-10-18b2',
#  'AUL-10-18b4',
#  'AUL-10-18b5',
#  'AUL10-01',
#  'BAV-33-01b2',
#  'BAV-33-01b3',
#  'BAV-33-01b4',
#  'BAV-33-02b2',
#  'BAV-33-02b3',
#  'BAV-33-02b4',
#  'BAV-33-03b2',
#  'BAV-33-03b3',
#  'BAV-33-03b4',
#  'BAV-33-04b2',
#  'BAV-33-04b3',
#  'BAV-33-04b4',
#  'BAV-33-05b2',
#  'BAV-33-05b3',
#  'BAV-33-05b4',
#  'BAV-33-07b2',
#  'BAV-33-07b3',
#  'BAV-33-07b4',
#  'BAV-33-08b2',
#  'BAV-33-08b3',
#  'BAV-33-08b4',
#  'BAV-33-11b2',
#  'BAV-33-11b3',
#  'BAV-33-11b4',
#  'BAV-33-12b2',
#  'BAV-33-12b3',
#  'BAV-33-12b4',
#  'BAV-33-13b2',
#  'BAV-33-13b3',
#  'BAV-33-13b4',
#  'BAV-33-14b2',
#  'BAV-33-14b3',
#  'BAV-33-14b4',
#  'BAV-33-16b2',
#  'BAV-33-16b3',
#  'BAV-33-16b4',
#  'BON-20-02b2',
#  'BON-20-02b3',
#  'BON-20-02b5',
#  'BON-20-03b2',
#  'BON-20-03b3',
#  'BON-20-03b5',
#  'BON-20-04b2',
#  'BON-20-04b3',
#  'BON-20-04b5',
#  'BON-20-11b2',
#  'BON-20-11b3',
#  'BON-20-11b5',
#  'BON-20-15b2',
#  'BON-20-15b3',
#  'BON-20-15b5',
#  'BON-20-18b2',
#  'BON-20-18b3',
#  'BON-20-18b5',
#  'BON-20-19b2',
#  'BON-20-19b3',
#  'BON-20-19b5',
#  'BON-20-21b2',
#  'BON-20-21b3',
#  'BON-20-21b5',
#  'BON-20-23b2',
#  'BON-20-23b3',
#  'BON-20-23b5',
#  'BON-20-24b2',
#  'BON-20-24b3',
#  'BON-20-24b5',
#  'BON-20-26b2',
#  'BON-20-26b3',
#  'BON-20-26b5',
#  'BON-20-27b2',
#  'BON-20-27b3',
#  'BON-20-27b5',
#  'BON20-02',
#  'ES-PP-01-01',
#  'ES-PP-01-02',
#  'ES-PP-01-03',
#  'ES-PP-01-04',
#  'ES-PP-01-05',
#  'ES-PP-01-06',
#  'ES-PP-01-07',
#  'ES-PP-01-08',
#  'ES-PP-01-09',
#  'ES-PP-01-10',
#  'ES-PP-01-11',
#  'ES-PP-01-12',
#  'ES-PP-01-13',
#  'ES-PP-01-14',
#  'ES-PP-01-15',
#  'ES-PP-01-16',
#  'ES-PP-01-17',
#  'ES-PP-01-18',
#  'ES-PP-01-19',
#  'ES-PP-01-20',
#  'ES-PP-01-21',
#  'ES-PP-01-22',
#  'ES-PP-01-23',
#  'ES-PP-01-24',
#  'ES-PP-01-25',
#  'ES-PP-02-01',
#  'ES-PP-02-02',
#  'ES-PP-02-03',
#  'ES-PP-02-04',
#  'ES-PP-02-05',
#  'ES-PP-02-06',
#  'ES-PP-02-07',
#  'ES-PP-02-08',
#  'ES-PP-02-09',
#  'ES-PP-02-10',
#  'ES-PP-02-11',
#  'ES-PP-02-12',
#  'ES-PP-02-13',
#  'ES-PP-02-14',
#  'ES-PP-02-15',
#  'ES-PP-02-16',
#  'ES-PP-02-17',
#  'ES-PP-02-18',
#  'ES-PP-02-19',
#  'ES-PP-02-20',
#  'ES-PP-02-21',
#  'ES-PP-02-22',
#  'ES-PP-02-23',
#  'ES-PP-02-24',
#  'ES-PP-02-25',
#  'ES-PP-03-01',
#  'ES-PP-03-02',
#  'ES-PP-03-03',
#  'ES-PP-03-04',
#  'ES-PP-03-05',
#  'ES-PP-03-06',
#  'ES-PP-03-07',
#  'ES-PP-03-08',
#  'ES-PP-03-09',
#  'ES-PP-03-10',
#  'ES-PP-03-11',
#  'ES-PP-03-12',
#  'ES-PP-03-13',
#  'ES-PP-03-14',
#  'ES-PP-03-15',
#  'ES-PP-03-16',
#  'ES-PP-03-17',
#  'ES-PP-03-18',
#  'ES-PP-03-19',
#  'ES-PP-03-20',
#  'ES-PP-03-21',
#  'ES-PP-03-22',
#  'ES-PP-03-23',
#  'ES-PP-03-24',
#  'ES-PP-03-25',
#  'ES-PP-04-01',
#  'ES-PP-04-02',
#  'ES-PP-04-03',
#  'ES-PP-04-04',
#  'ES-PP-04-05',
#  'ES-PP-04-06',
#  'ES-PP-04-07',
#  'ES-PP-04-08',
#  'ES-PP-04-09',
#  'ES-PP-04-10',
#  'ES-PP-04-11',
#  'ES-PP-04-12',
#  'ES-PP-04-13',
#  'ES-PP-04-14',
#  'ES-PP-04-15',
#  'ES-PP-04-16',
#  'ES-PP-04-17',
#  'ES-PP-04-18',
#  'ES-PP-04-19',
#  'ES-PP-04-20',
#  'ES-PP-04-21',
#  'ES-PP-04-22',
#  'ES-PP-04-23',
#  'ES-PP-04-24',
#  'ES-PP-04-25',
#  'ES-PP-05-01',
#  'ES-PP-05-02',
#  'ES-PP-05-03',
#  'ES-PP-05-04',
#  'ES-PP-05-05',
#  'ES-PP-05-06',
#  'ES-PP-05-07',
#  'ES-PP-05-08',
#  'ES-PP-05-09',
#  'ES-PP-05-10',
#  'ES-PP-05-11',
#  'ES-PP-05-12',
#  'ES-PP-05-13',
#  'ES-PP-05-14',
#  'ES-PP-05-15',
#  'ES-PP-05-16',
#  'ES-PP-05-17',
#  'ES-PP-05-18',
#  'ES-PP-05-19',
#  'ES-PP-05-20',
#  'ES-PP-05-21',
#  'ES-PP-05-22',
#  'ES-PP-05-23',
#  'ES-PP-05-24',
#  'ES-PP-05-25',
#  'ES-PP-06-01',
#  'ES-PP-06-02',
#  'ES-PP-06-03',
#  'ES-PP-06-04',
#  'ES-PP-06-05',
#  'ES-PP-06-06',
#  'ES-PP-06-07',
#  'ES-PP-06-08',
#  'ES-PP-06-09',
#  'ES-PP-06-10',
#  'ES-PP-06-11',
#  'ES-PP-06-12',
#  'ES-PP-06-13',
#  'ES-PP-06-14',
#  'ES-PP-06-15',
#  'ES-PP-06-16',
#  'ES-PP-06-17',
#  'ES-PP-06-18',
#  'ES-PP-06-19',
#  'ES-PP-06-20',
#  'ES-PP-06-21',
#  'ES-PP-06-22',
#  'ES-PP-06-23',
#  'ES-PP-06-24',
#  'ES-PP-06-25',
#  'ES-PP-07-01',
#  'ES-PP-07-02',
#  'ES-PP-07-03',
#  'ES-PP-07-04',
#  'ES-PP-07-05',
#  'ES-PP-07-06',
#  'ES-PP-07-07',
#  'ES-PP-07-08',
#  'ES-PP-07-09',
#  'ES-PP-07-10',
#  'ES-PP-07-11',
#  'ES-PP-07-12',
#  'ES-PP-07-13',
#  'ES-PP-07-14',
#  'ES-PP-07-15',
#  'ES-PP-07-16',
#  'ES-PP-07-17',
#  'ES-PP-07-18',
#  'ES-PP-07-19',
#  'ES-PP-07-20',
#  'ES-PP-07-21',
#  'ES-PP-07-22',
#  'ES-PP-07-23',
#  'ES-PP-07-24',
#  'ES-PP-07-25',
#  'ES-PP-08-01',
#  'ES-PP-08-02',
#  'ES-PP-08-03',
#  'ES-PP-08-04',
#  'ES-PP-08-05',
#  'ES-PP-08-06',
#  'ES-PP-08-07',
#  'ES-PP-08-08',
#  'ES-PP-08-09',
#  'ES-PP-08-10',
#  'ES-PP-08-11',
#  'ES-PP-08-12',
#  'ES-PP-08-13',
#  'ES-PP-08-14',
#  'ES-PP-08-15',
#  'ES-PP-08-16',
#  'ES-PP-08-17',
#  'ES-PP-08-18',
#  'ES-PP-08-19',
#  'ES-PP-08-20',
#  'ES-PP-08-21',
#  'ES-PP-08-22',
#  'ES-PP-08-23',
#  'ES-PP-08-24',
#  'ES-PP-08-25',
#  'FR-PP-09-01',
#  'FR-PP-09-02',
#  'FR-PP-09-03',
#  'FR-PP-09-04',
#  'FR-PP-09-05',
#  'FR-PP-09-09',
#  'FR-PP-09-10',
#  'FR-PP-09-11',
#  'FR-PP-09-12',
#  'FR-PP-09-13',
#  'FR-PP-09-14',
#  'FR-PP-09-15',
#  'FR-PP-09-16',
#  'FR-PP-09-17',
#  'FR-PP-09-18',
#  'FR-PP-09-21',
#  'FR-PP-09-22',
#  'FR-PP-09-23',
#  'FR-PP-09-24',
#  'FR-PP-09-25',
#  'FR-PP-09-26',
#  'FR-PP-09-27',
#  'FR-PP-09-28',
#  'FR-PP-09-29',
#  'FR-PP-09-30',
#  'FR-PP-10-01',
#  'FR-PP-10-02',
#  'FR-PP-10-03',
#  'FR-PP-10-04',
#  'FR-PP-10-05',
#  'FR-PP-10-06',
#  'FR-PP-10-07',
#  'FR-PP-10-08',
#  'FR-PP-10-09',
#  'FR-PP-10-10',
#  'FR-PP-10-11',
#  'FR-PP-10-12',
#  'FR-PP-10-13',
#  'FR-PP-10-14',
#  'FR-PP-10-15',
#  'FR-PP-10-16',
#  'FR-PP-10-17',
#  'FR-PP-10-18',
#  'FR-PP-10-19',
#  'FR-PP-10-20',
#  'FR-PP-10-21',
#  'FR-PP-10-22',
#  'FR-PP-10-23',
#  'FR-PP-10-24',
#  'FR-PP-10-25',
#  'FR-PP-11-01',
#  'FR-PP-11-02',
#  'FR-PP-11-03',
#  'FR-PP-11-04',
#  'FR-PP-11-05',
#  'FR-PP-11-06',
#  'FR-PP-11-07',
#  'FR-PP-11-08',
#  'FR-PP-11-09',
#  'FR-PP-11-10',
#  'FR-PP-11-11',
#  'FR-PP-11-12',
#  'FR-PP-11-13',
#  'FR-PP-11-14',
#  'FR-PP-11-15',
#  'FR-PP-11-16',
#  'FR-PP-11-17',
#  'FR-PP-11-18',
#  'FR-PP-11-19',
#  'FR-PP-11-20',
#  'FR-PP-11-21',
#  'FR-PP-11-22',
#  'FR-PP-11-23',
#  'FR-PP-11-24',
#  'FR-PP-11-25',
#  'FR-PP-12-01',
#  'FR-PP-12-02',
#  'FR-PP-12-03',
#  'FR-PP-12-04',
#  'FR-PP-12-05',
#  'FR-PP-12-06',
#  'FR-PP-12-07',
#  'FR-PP-12-08',
#  'FR-PP-12-09',
#  'FR-PP-12-10',
#  'FR-PP-12-11',
#  'FR-PP-12-12',
#  'FR-PP-12-13',
#  'FR-PP-12-14',
#  'FR-PP-12-15',
#  'FR-PP-12-16',
#  'FR-PP-12-17',
#  'FR-PP-12-18',
#  'FR-PP-12-19',
#  'FR-PP-12-22',
#  'FR-PP-12-23',
#  'FR-PP-12-24',
#  'FR-PP-12-25',
#  'FR-PP-12-26',
#  'FR-PP-13-01',
#  'FR-PP-13-02',
#  'FR-PP-13-03',
#  'FR-PP-13-04',
#  'FR-PP-13-05',
#  'FR-PP-13-06',
#  'FR-PP-13-07',
#  'FR-PP-13-08',
#  'FR-PP-13-09',
#  'FR-PP-13-10',
#  'FR-PP-13-11',
#  'FR-PP-13-12',
#  'FR-PP-13-13',
#  'FR-PP-13-14',
#  'FR-PP-13-15',
#  'FR-PP-13-16',
#  'FR-PP-13-17',
#  'FR-PP-13-18',
#  'FR-PP-13-19',
#  'FR-PP-13-20',
#  'FR-PP-13-21',
#  'FR-PP-13-22',
#  'FR-PP-13-23',
#  'FR-PP-13-24',
#  'FR-PP-13-25',
#  'FR-PP-14-01',
#  'FR-PP-14-02',
#  'FR-PP-14-03',
#  'FR-PP-14-04',
#  'FR-PP-14-05',
#  'FR-PP-14-06',
#  'FR-PP-14-07',
#  'FR-PP-14-08',
#  'FR-PP-14-09',
#  'FR-PP-14-10',
#  'FR-PP-14-11',
#  'FR-PP-14-12',
#  'FR-PP-14-13',
#  'FR-PP-14-14',
#  'FR-PP-14-15',
#  'FR-PP-14-16',
#  'FR-PP-14-17',
#  'FR-PP-14-18',
#  'FR-PP-14-19',
#  'FR-PP-14-20',
#  'FR-PP-14-21',
#  'FR-PP-14-22',
#  'FR-PP-14-23',
#  'FR-PP-14-24',
#  'FR-PP-14-25',
#  'FR-PP-16-21',
#  'IT-PP-15-01',
#  'IT-PP-15-02',
#  'IT-PP-15-03',
#  'IT-PP-15-04',
#  'IT-PP-15-05',
#  'IT-PP-15-06',
#  'IT-PP-15-07',
#  'IT-PP-15-08',
#  'IT-PP-15-09',
#  'IT-PP-15-10',
#  'IT-PP-15-11',
#  'IT-PP-15-12',
#  'IT-PP-15-13',
#  'IT-PP-15-14',
#  'IT-PP-15-15',
#  'IT-PP-15-16',
#  'IT-PP-15-17',
#  'IT-PP-15-18',
#  'IT-PP-15-19',
#  'IT-PP-15-20',
#  'IT-PP-15-21',
#  'IT-PP-15-22',
#  'IT-PP-15-23',
#  'IT-PP-15-24',
#  'IT-PP-15-25',
#  'IT-PP-16-01',
#  'IT-PP-16-02',
#  'IT-PP-16-03',
#  'IT-PP-16-04',
#  'IT-PP-16-05',
#  'IT-PP-16-06',
#  'IT-PP-16-07',
#  'IT-PP-16-08',
#  'IT-PP-16-09',
#  'IT-PP-16-10',
#  'IT-PP-16-11',
#  'IT-PP-16-12',
#  'IT-PP-16-13',
#  'IT-PP-16-14',
#  'IT-PP-16-15',
#  'IT-PP-16-16',
#  'IT-PP-16-17',
#  'IT-PP-16-18',
#  'IT-PP-16-19',
#  'IT-PP-16-20',
#  'IT-PP-16-21',
#  'IT-PP-16-22',
#  'IT-PP-16-23',
#  'IT-PP-16-24',
#  'IT-PP-16-25',
#  'IT-PP-17-01',
#  'IT-PP-17-02',
#  'IT-PP-17-03',
#  'IT-PP-17-04',
#  'IT-PP-17-05',
#  'IT-PP-17-06',
#  'IT-PP-17-07',
#  'IT-PP-17-08',
#  'IT-PP-17-09',
#  'IT-PP-17-10',
#  'IT-PP-17-11',
#  'IT-PP-17-12',
#  'IT-PP-17-13',
#  'IT-PP-17-14',
#  'IT-PP-17-15',
#  'IT-PP-17-16',
#  'IT-PP-17-17',
#  'IT-PP-17-18',
#  'IT-PP-17-19',
#  'IT-PP-17-20',
#  'IT-PP-17-21',
#  'IT-PP-17-22',
#  'IT-PP-17-23',
#  'IT-PP-17-24',
#  'IT-PP-17-25',
#  'IT-PP-18-01',
#  'IT-PP-18-02',
#  'IT-PP-18-03',
#  'IT-PP-18-04',
#  'IT-PP-18-05',
#  'IT-PP-18-06',
#  'IT-PP-18-07',
#  'IT-PP-18-08',
#  'IT-PP-18-09',
#  'IT-PP-18-10',
#  'IT-PP-18-11',
#  'IT-PP-18-12',
#  'IT-PP-18-13',
#  'IT-PP-18-14',
#  'IT-PP-18-15',
#  'IT-PP-18-16',
#  'IT-PP-18-17',
#  'IT-PP-18-18',
#  'IT-PP-18-19',
#  'IT-PP-18-20',
#  'IT-PP-18-21',
#  'IT-PP-18-22',
#  'IT-PP-18-23',
#  'IT-PP-18-24',
#  'IT-PP-18-25',
#  'IT-PP-19-01',
#  'IT-PP-19-02',
#  'IT-PP-19-03',
#  'IT-PP-19-04',
#  'IT-PP-19-05',
#  'IT-PP-19-06',
#  'IT-PP-19-07',
#  'IT-PP-19-08',
#  'IT-PP-19-10',
#  'IT-PP-19-11',
#  'IT-PP-19-12',
#  'IT-PP-19-13',
#  'IT-PP-19-14',
#  'IT-PP-19-15',
#  'IT-PP-19-16',
#  'IT-PP-19-18',
#  'IT-PP-19-20',
#  'IT-PP-19-21',
#  'IT-PP-19-22',
#  'IT-PP-19-23',
#  'IT-PP-19-24',
#  'IT-PP-19-25',
#  'IT-PP-19-26',
#  'IT-PP-19-27',
#  'IT-PP-19-29',
#  'IT-PP-20-01',
#  'IT-PP-20-04',
#  'IT-PP-20-05',
#  'IT-PP-20-06',
#  'IT-PP-20-07',
#  'IT-PP-20-08',
#  'IT-PP-20-09',
#  'IT-PP-20-10',
#  'IT-PP-20-11',
#  'IT-PP-20-13',
#  'IT-PP-20-14',
#  'IT-PP-20-15',
#  'IT-PP-20-16',
#  'IT-PP-20-17',
#  'IT-PP-20-18',
#  'IT-PP-20-19',
#  'IT-PP-20-20',
#  'IT-PP-20-21',
#  'IT-PP-20-22',
#  'IT-PP-20-24',
#  'IT-PP-20-25',
#  'IT-PP-20-26',
#  'IT-PP-20-28',
#  'IT-PP-20-29',
#  'IT-PP-20-30',
#  'LAR-30-01b5',
#  'LAR-30-02b5',
#  'LAR-30-03b5',
#  'LAR-30-04b5',
#  'LAR-30-06b5',
#  'LAR-30-07b5',
#  'LAR-30-08b5',
#  'LAR-30-09b5',
#  'LAR-30-11b5',
#  'LAR-30-12b5',
#  'LAR-30-13b5',
#  'LAR-30-14b5',
#  'LCor-01',
#  'LCor-02',
#  'LCor-03',
#  'LCor-04',
#  'LCor-05',
#  'LCor-06',
#  'LCor-07',
#  'LCor-08',
#  'LCor-09',
#  'LCor-10',
#  'LCor-11',
#  'LCor-12',
#  'LCor-13',
#  'LCor-14',
#  'LCor-15',
#  'LCor-16',
#  'LCor-17',
#  'LCor-18',
#  'LCor-19',
#  'LCor-20',
#  'LCor-21',
#  'LCor-22',
#  'LCor-23',
#  'LCor-24',
#  'Leir-01',
#  'Leir-03',
#  'Leir-04',
#  'Leir-05',
#  'Leir-07',
#  'Leir-08',
#  'Leir-09',
#  'Leir-14',
#  'Leir-15',
#  'Leir-16',
#  'Leir-19',
#  'Leir-24',
#  'Leir-25',
#  'Leir-26',
#  'Leir-27',
#  'Leir-28',
#  'Leir-29',
#  'Leir-30',
#  'Leir-39',
#  'OSP-8-19b1',
#  'OSP-8-20b1',
#  'PAS-23-01b2',
#  'PAS-23-01b3',
#  'PAS-23-01b4',
#  'PAS-23-02b2',
#  'PAS-23-02b3',
#  'PAS-23-02b4',
#  'PAS-23-03b2',
#  'PAS-23-03b3',
#  'PAS-23-03b4',
#  'PAS-23-04b2',
#  'PAS-23-04b3',
#  'PAS-23-04b4',
#  'PAS-23-07b3',
#  'PAS-23-07b4',
#  'PAS-23-08b2',
#  'PAS-23-08b3',
#  'PAS-23-08b4',
#  'PAS-23-09b2',
#  'PAS-23-09b3',
#  'PAS-23-09b4',
#  'PAS-23-15b2',
#  'PAS-23-15b3',
#  'PAS-23-15b4',
#  'PAS-23-19b2',
#  'PAS-23-19b3',
#  'PAS-23-19b4',
#  'PAS-23-21b2',
#  'PAS-23-21b3',
#  'PAS-23-21b4',
#  'PAS-23-22b2',
#  'PAS-23-22b3',
#  'PAS-23-22b4',
#  'PAS-23-24b2',
#  'PAS-23-24b3',
#  'PIA-15-01b2',
#  'PIA-15-01b3',
#  'PIA-15-01b5',
#  'PIA-15-11b2',
#  'PIA-15-11b3',
#  'PIA-15-11b5',
#  'PIA-15-12b2',
#  'PIA-15-12b3',
#  'PIA-15-12b5',
#  'PIA-15-13b2',
#  'PIA-15-13b3',
#  'PIA-15-13b5',
#  'PIA-15-14b2',
#  'PIA-15-14b3',
#  'PIA-15-15b2',
#  'PIA-15-15b3',
#  'PIA-15-15b5',
#  'PIA-15-16b2',
#  'PIA-15-16b3',
#  'PIA-15-16b5',
#  'PIA-15-18b2',
#  'PIA-15-18b3',
#  'PIA-15-18b5',
#  'PIA-15-19b2',
#  'PIA-15-19b3',
#  'PIA-15-19b5',
#  'PIA-15-21b2',
#  'PIA-15-21b3',
#  'PIA-15-21b5',
#  'PIA-15-24b2',
#  'PIA-15-24b3',
#  'PIA-15-24b5',
#  'PIA-15-25b2',
#  'PIA-15-25b3',
#  'PIA-15-25b5',
#  'PTA-11-02b2',
#  'PTA-11-02b3',
#  'PTA-11-02b5',
#  'PTA-11-11b2',
#  'PTA-11-11b3',
#  'PTA-11-11b5',
#  'PTA-11-12b2',
#  'PTA-11-12b3',
#  'PTA-11-12b5',
#  'PTA-11-14b2',
#  'PTA-11-14b3',
#  'PTA-11-14b5',
#  'PTA-11-15b2',
#  'PTA-11-15b3',
#  'PTA-11-15b5',
#  'PTA-11-18b2',
#  'PTA-11-18b3',
#  'PTA-11-18b5',
#  'PTA-11-19b2',
#  'PTA-11-19b3',
#  'PTA-11-19b5',
#  'PTA-11-23b2',
#  'PTA-11-23b3',
#  'PTA-11-23b5',
#  'PTA-11-25b2',
#  'PTA-11-25b3',
#  'PTA-11-25b5',
#  'PTA-11-27b2',
#  'PTA-11-27b3',
#  'PTA-11-27b5',
#  'PTA-11-28b2',
#  'PTA-11-28b3',
#  'PTA-11-28b5',
#  'PTA-11-31b2',
#  'PTA-11-31b3',
#  'PTA-11-31b5',
#  'RES-2-03b2',
#  'RES-2-03b4',
#  'RES-2-03b5',
#  'RES-2-04b2',
#  'RES-2-04b4',
#  'RES-2-04b5',
#  'RES-2-06b2',
#  'RES-2-06b4',
#  'RES-2-06b5',
#  'RES-2-08b2',
#  'RES-2-08b4',
#  'RES-2-08b5',
#  'RES-2-09b2',
#  'RES-2-09b4',
#  'RES-2-09b5',
#  'RES-2-11b2',
#  'RES-2-11b4',
#  'RES-2-11b5',
#  'RES-2-14b2',
#  'RES-2-14b4',
#  'RES-2-14b5',
#  'RES-2-18b2',
#  'RES-2-18b4',
#  'RES-2-18b5',
#  'RES-2-19b2',
#  'RES-2-19b4',
#  'RES-2-19b5',
#  'RES-2-22b2',
#  'RES-2-22b4',
#  'RES-2-22b5',
#  'RES-2-23b2',
#  'RES-2-23b4',
#  'RES-2-23b5',
#  'RES-2-24b2',
#  'RES-2-24b4',
#  'RES-2-24b5',
#  'RES2-09',
#  'RES2-11',
#  'SOR-5-04b2',
#  'SOR-5-04b4',
#  'SOR-5-04b5',
#  'SOR-5-07b2',
#  'SOR-5-07b4',
#  'SOR-5-07b5',
#  'SOR-5-09b2',
#  'SOR-5-09b5',
#  'SOR-5-11b2',
#  'SOR-5-11b4',
#  'SOR-5-11b5',
#  'SOR-5-12b2',
#  'SOR-5-12b4',
#  'SOR-5-12b5',
#  'SOR-5-15b2',
#  'SOR-5-15b4',
#  'SOR-5-15b5',
#  'SOR-5-16b2',
#  'SOR-5-16b4',
#  'SOR-5-16b5',
#  'SOR-5-17b2',
#  'SOR-5-17b4',
#  'SOR-5-17b5',
#  'SOR-5-21b2',
#  'SOR-5-21b4',
#  'SOR-5-21b5',
#  'SOR-5-22b2',
#  'SOR-5-22b4',
#  'SOR-5-22b5',
#  'SOR-5-24b2',
#  'SOR-5-24b4',
#  'SOR-5-24b5',
#  'SOR-5-26b2',
#  'SOR-5-26b4',
#  'SOR-5-26b5',
#  'SOR5-01',
#  'SiMe-01',
#  'SiMe-02',
#  'SiMe-03',
#  'SiMe-04',
#  'SiMe-05',
#  'SiMe-06',
#  'SiMe-07',
#  'SiMe-08',
#  'SiMe-09',
#  'SiMe-10',
#  'SiMe-11',
#  'SiMe-12',
#  'SiMe-13',
#  'SiMe-14',
#  'SiMe-15',
#  'SiMe-16',
#  'SiMe-17',
#  'SiMe-18',
#  'SiMe-19',
#  'SiMe-20',
#  'SiMe-21',
#  'SiMe-22',
#  'SiMe-23',
#  'SiMe-24',
#  'TAEDA1',
#  'TAEDA2',
#  'TAEDA3',
#  'TAEDA4',
#  'TAEDA5',
#  'TMJT-01',
#  'TMJT-02',
#  'TMJT-03',
#  'TMJT-04',
#  'TMJT-05',
#  'TMJT-06',
#  'TMJT-07',
#  'TMJT-08',
#  'TMJT-09',
#  'TMJT-10',
#  'TMJT-11',
#  'TMJT-12',
#  'TMJT-13',
#  'TMJT-14',
#  'TMJT-15',
#  'TMJT-16',
#  'TMJT-17',
#  'TMJT-18',
#  'TMJT-19',
#  'TMJT-20',
#  'TMJT-21',
#  'TMJT-22',
#  'TMJT-23',
#  'TMJT-24',
#  'TOV-6-01b1',
#  'TOV-6-02b1',
#  'TOV-6-10b1',
#  'TOV-6-11b1',
#  'TOV-6-12b1',
#  'TOV-6-13b1',
#  'TOV-6-14b1',
#  'TOV-6-16b1',
#  'TOV-6-17b1',
#  'TOV-6-18b1',
#  'TOV-6-19b1',
#  'TOV-6-20b1',
#  'Taeda1bis',
#  'Taeda2bis',
#  'Taeda3bis',
#  'Taeda4bis',
#  'Taeda5bis',
#  'Tunisia1',
#  'Tunisia2',
#  'Tunisia3',
#  'Tunisia4',
#  'Tunisia5',
#  'Tunisia6',
#  'Tunisia7',
#  'Tunisia8',
#  'VAL-19-01b2',
#  'VAL-19-01b3',
#  'VAL-19-01b5',
#  'VAL-19-11b2',
#  'VAL-19-11b3',
#  'VAL-19-11b5',
#  'VAL-19-12b2',
#  'VAL-19-12b3',
#  'VAL-19-12b5',
#  'VAL-19-13b2',
#  'VAL-19-13b3',
#  'VAL-19-13b5',
#  'VAL-19-14b2',
#  'VAL-19-14b3',
#  'VAL-19-14b5',
#  'VAL-19-17b2',
#  'VAL-19-17b3',
#  'VAL-19-17b5',
#  'VAL-19-18b2',
#  'VAL-19-18b3',
#  'VAL-19-18b5',
#  'VAL-19-21b2',
#  'VAL-19-21b3',
#  'VAL-19-21b5',
#  'VAL-19-22b2',
#  'VAL-19-22b3',
#  'VAL-19-22b5',
#  'VAL-19-23b2',
#  'VAL-19-23b3',
#  'VAL-19-23b5',
#  'VAL-19-24b2',
#  'VAL-19-24b3',
#  'VAL-19-24b5',
#  'VAL-19-27b2',
#  'VAL-19-27b3',
#  'VAL-19-27b5',
#  'VAL19-01',
#  'VEN-25-02b3',
#  'VEN-25-02b4',
#  'VEN-25-03b2',
#  'VEN-25-03b3',
#  'VEN-25-03b4',
#  'VEN-25-06b2',
#  'VEN-25-06b3',
#  'VEN-25-06b4',
#  'VEN-25-09b2',
#  'VEN-25-09b3',
#  'VEN-25-09b4',
#  'VEN-25-11b2',
#  'VEN-25-11b3',
#  'VEN-25-11b4',
#  'VEN-25-12b2',
#  'VEN-25-12b3',
#  'VEN-25-12b4',
#  'VEN-25-13b2',
#  'VEN-25-13b3',
#  'VEN-25-13b4',
#  'VEN-25-15b2',
#  'VEN-25-15b3',
#  'VEN-25-15b4',
#  'VEN-25-17b2',
#  'VEN-25-17b3',
#  'VEN-25-17b4',
#  'VEN-25-19b2',
#  ...]

# %%
samples_fn = '/wrk/Gen_Tree/Pinus_pinaster/metadata_Pinastr_for_scikit_SORTED.txt'
samples = pandas.read_csv(samples_fn, sep='\t')
samples.head()
# Out:
#             ID Population
# 0  ES-PP-01-01    ES-PP-1
# 1  ES-PP-01-02    ES-PP-1
# 2  ES-PP-01-03    ES-PP-1
# 3  ES-PP-01-04    ES-PP-1
# 4  ES-PP-01-05    ES-PP-1

# %%
samples.Population.value_counts()
# Out:
# FR-PP-13    25
# IT-PP-18    25
# IT-PP-19    25
# IT-PP-20    25
# ES-PP-4     25
# IT-PP-15    25
# FR-PP-9     25
# FR-PP-11    25
# IT-PP-16    25
# IT-PP-17    25
# ES-PP-5     25
# FR-PP-10    25
# ES-PP-2     25
# ES-PP-3     25
# ES-PP-1     25
# FR-PP-14    25
# ES-PP-8     25
# ES-PP-7     25
# ES-PP-6     25
# TMJT        24
# SiMe        24
# LCor        24
# FR-PP-12    24
# Leir        19
# Tunisia      8
# FR-PP-16     1
# Name: Population, dtype: int64

# %%
calldata = callset['calldata']

# %%
genotypes = allel.GenotypeChunkedArray(calldata['GT'])
genotypes
# Out:
# <GenotypeChunkedArray shape=(2263634, 599, 2) dtype=int8 chunks=(65536, 64, 2)
#    nbytes=2.5G cbytes=271.3M cratio=9.5
#    compression=gzip compression_opts=1
#    values=h5py._hl.dataset.Dataset>

# %%
ac = genotypes.count_alleles()
ac
# Out:
# <AlleleCountsChunkedArray shape=(2263634, 2) dtype=int32 chunks=(70739, 2)
#    nbytes=17.3M cbytes=5.7M cratio=3.0
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
#biallelic = (ac.max_allele() == 1)

# %%
#genotypes_Biallelic_subset = genotypes.compress(biallelic)
#genotypes_Biallelic_subset

# %%
n_variants = len(genotypes)
n_variants
# Out:
# 2263634

# %%
pc_missing = genotypes.count_missing(axis=0)[:] * 100 / n_variants
pc_het = genotypes.count_het(axis=0)[:] * 100 / n_variants
#pc_missing

# %%
samples
# Out:
#               ID Population
# 0    ES-PP-01-01    ES-PP-1
# 1    ES-PP-01-02    ES-PP-1
# 2    ES-PP-01-03    ES-PP-1
# 3    ES-PP-01-04    ES-PP-1
# 4    ES-PP-01-05    ES-PP-1
# 5    ES-PP-01-06    ES-PP-1
# 6    ES-PP-01-07    ES-PP-1
# 7    ES-PP-01-08    ES-PP-1
# 8    ES-PP-01-09    ES-PP-1
# 9    ES-PP-01-10    ES-PP-1
# 10   ES-PP-01-11    ES-PP-1
# 11   ES-PP-01-12    ES-PP-1
# 12   ES-PP-01-13    ES-PP-1
# 13   ES-PP-01-14    ES-PP-1
# 14   ES-PP-01-15    ES-PP-1
# 15   ES-PP-01-16    ES-PP-1
# 16   ES-PP-01-17    ES-PP-1
# 17   ES-PP-01-18    ES-PP-1
# 18   ES-PP-01-19    ES-PP-1
# 19   ES-PP-01-20    ES-PP-1
# 20   ES-PP-01-21    ES-PP-1
# 21   ES-PP-01-22    ES-PP-1
# 22   ES-PP-01-23    ES-PP-1
# 23   ES-PP-01-24    ES-PP-1
# 24   ES-PP-01-25    ES-PP-1
# 25   ES-PP-02-01    ES-PP-2
# 26   ES-PP-02-02    ES-PP-2
# 27   ES-PP-02-03    ES-PP-2
# 28   ES-PP-02-04    ES-PP-2
# 29   ES-PP-02-05    ES-PP-2
# ..           ...        ...
# 569      TMJT-03       TMJT
# 570      TMJT-04       TMJT
# 571      TMJT-05       TMJT
# 572      TMJT-06       TMJT
# 573      TMJT-07       TMJT
# 574      TMJT-08       TMJT
# 575      TMJT-09       TMJT
# 576      TMJT-10       TMJT
# 577      TMJT-11       TMJT
# 578      TMJT-12       TMJT
# 579      TMJT-13       TMJT
# 580      TMJT-14       TMJT
# 581      TMJT-15       TMJT
# 582      TMJT-16       TMJT
# 583      TMJT-17       TMJT
# 584      TMJT-18       TMJT
# 585      TMJT-19       TMJT
# 586      TMJT-20       TMJT
# 587      TMJT-21       TMJT
# 588      TMJT-22       TMJT
# 589      TMJT-23       TMJT
# 590      TMJT-24       TMJT
# 591     Tunisia1    Tunisia
# 592     Tunisia2    Tunisia
# 593     Tunisia3    Tunisia
# 594     Tunisia4    Tunisia
# 595     Tunisia5    Tunisia
# 596     Tunisia6    Tunisia
# 597     Tunisia7    Tunisia
# 598     Tunisia8    Tunisia
#
# [599 rows x 2 columns]

# %%
samples.Population.unique()
# Out:
# array(['ES-PP-1', 'ES-PP-2', 'ES-PP-3', 'ES-PP-4', 'ES-PP-5', 'ES-PP-6',
#        'ES-PP-7', 'ES-PP-8', 'FR-PP-9', 'FR-PP-10', 'FR-PP-11',
#        'FR-PP-12', 'FR-PP-13', 'FR-PP-14', 'FR-PP-16', 'IT-PP-15',
#        'IT-PP-16', 'IT-PP-17', 'IT-PP-18', 'IT-PP-19', 'IT-PP-20', 'LCor',
#        'Leir', 'SiMe', 'TMJT', 'Tunisia'], dtype=object)

# %%
samples.Population
# Out:
# 0      ES-PP-1
# 1      ES-PP-1
# 2      ES-PP-1
# 3      ES-PP-1
# 4      ES-PP-1
# 5      ES-PP-1
# 6      ES-PP-1
# 7      ES-PP-1
# 8      ES-PP-1
# 9      ES-PP-1
# 10     ES-PP-1
# 11     ES-PP-1
# 12     ES-PP-1
# 13     ES-PP-1
# 14     ES-PP-1
# 15     ES-PP-1
# 16     ES-PP-1
# 17     ES-PP-1
# 18     ES-PP-1
# 19     ES-PP-1
# 20     ES-PP-1
# 21     ES-PP-1
# 22     ES-PP-1
# 23     ES-PP-1
# 24     ES-PP-1
# 25     ES-PP-2
# 26     ES-PP-2
# 27     ES-PP-2
# 28     ES-PP-2
# 29     ES-PP-2
#         ...
# 569       TMJT
# 570       TMJT
# 571       TMJT
# 572       TMJT
# 573       TMJT
# 574       TMJT
# 575       TMJT
# 576       TMJT
# 577       TMJT
# 578       TMJT
# 579       TMJT
# 580       TMJT
# 581       TMJT
# 582       TMJT
# 583       TMJT
# 584       TMJT
# 585       TMJT
# 586       TMJT
# 587       TMJT
# 588       TMJT
# 589       TMJT
# 590       TMJT
# 591    Tunisia
# 592    Tunisia
# 593    Tunisia
# 594    Tunisia
# 595    Tunisia
# 596    Tunisia
# 597    Tunisia
# 598    Tunisia
# Name: Population, Length: 599, dtype: object

# %%
def plot_genotype_frequency(pc, title):
    fig, ax = plt.subplots(figsize=(24, 5))
    sns.despine(ax=ax, offset=24)
    left = np.arange(len(pc))
    palette = sns.color_palette("hls", 30)
    pop2color = {'ES-PP-1': palette[7],
                 'ES-PP-2': palette[1],
                 'ES-PP-3': palette[2],
                 'ES-PP-4': palette[3],
                 'ES-PP-5': palette[4],
                 'ES-PP-6': palette[25],
                 'ES-PP-7': palette[6],
                 'ES-PP-8': palette[0],
                 'FR-PP-9': palette[8],
                 'FR-PP-10': palette[16],
                 'FR-PP-11': palette[23],
                 'FR-PP-12': palette[11],
                 'FR-PP-13': palette[20],
                 'FR-PP-14': palette[13],
                 'FR-PP-16': palette[15],
                 'IT-PP-15': palette[9],
                 'IT-PP-16': palette[17],
                 'IT-PP-17': palette[21],
                 'IT-PP-18': palette[19],
                 'IT-PP-19': palette[12],
                 'IT-PP-20': palette[18],
                 'LCor': palette[22],
                 'Leir': palette[10],
                 'SiMe': palette[24],
                 'TMJT': palette[5],
                 'Tunisia': palette[26]}
    colors = [pop2color[p] for p in samples.Population]
    ax.bar(left, pc, color=colors)
    ax.set_xlim(0, len(pc))
    ax.set_xlabel('Sample index')
    ax.set_ylabel('Percent calls')
    ax.set_title(title)
    handles = [mpl.patches.Patch(color=palette[7]),
               mpl.patches.Patch(color=palette[1]),
               mpl.patches.Patch(color=palette[2]),
               mpl.patches.Patch(color=palette[3]),
               mpl.patches.Patch(color=palette[4]),
               mpl.patches.Patch(color=palette[25]),
               mpl.patches.Patch(color=palette[6]),
               mpl.patches.Patch(color=palette[0]),
               mpl.patches.Patch(color=palette[8]),
               mpl.patches.Patch(color=palette[9]),
               mpl.patches.Patch(color=palette[23]),
               mpl.patches.Patch(color=palette[11]),
               mpl.patches.Patch(color=palette[20]),
               mpl.patches.Patch(color=palette[13]),
               mpl.patches.Patch(color=palette[15]),
               mpl.patches.Patch(color=palette[16]),
               mpl.patches.Patch(color=palette[17]),
               mpl.patches.Patch(color=palette[21]),
               mpl.patches.Patch(color=palette[19]),
               mpl.patches.Patch(color=palette[12]),
               mpl.patches.Patch(color=palette[18]),
               mpl.patches.Patch(color=palette[22]),
               mpl.patches.Patch(color=palette[10]),
               mpl.patches.Patch(color=palette[24]),
               mpl.patches.Patch(color=palette[5]),
               mpl.patches.Patch(color=palette[26])]
    ax.legend(handles=handles, labels=['ES-PP-1', 'ES-PP-2', 'ES-PP-3', 'ES-PP-4', 'ES-PP-5', 'ES-PP-6',
       'ES-PP-7', 'ES-PP-8', 'FR-PP-9', 'FR-PP-10', 'FR-PP-11',
       'FR-PP-12', 'FR-PP-13', 'FR-PP-14', 'FR-PP-16', 'IT-PP-15',
       'IT-PP-16', 'IT-PP-17', 'IT-PP-18', 'IT-PP-19', 'IT-PP-20', 'LCor',
       'Leir', 'SiMe', 'TMJT', 'Tunisia'], title='Population',
              bbox_to_anchor=(1, 1), loc='upper left')

# %%
plot_genotype_frequency(pc_missing, 'Missing')
plt.savefig('/wrk/Gen_Tree/Pinus_pinaster/Ppinaster_Missing_data_per_sample.pdf')

# %%
np.argsort(pc_missing)[-1]
# Out:
# 141

# %%
plot_genotype_frequency(pc_het, 'Heterozygosity')
plt.savefig('/wrk/Gen_Tree/Pinus_pinaster/Ppinaster_Heterozygosity.pdf')

# %%
palette = sns.color_palette("hls", 30)
pop_colours = {'ES-PP-1': palette[7],
                 'ES-PP-2': palette[1],
                 'ES-PP-3': palette[2],
                 'ES-PP-4': palette[3],
                 'ES-PP-5': palette[4],
                 'ES-PP-6': palette[25],
                 'ES-PP-7': palette[6],
                 'ES-PP-8': palette[0],
                 'FR-PP-9': palette[8],
                 'FR-PP-10': palette[16],
                 'FR-PP-11': palette[23],
                 'FR-PP-12': palette[11],
                 'FR-PP-13': palette[20],
                 'FR-PP-14': palette[13],
                 'FR-PP-16': palette[15],
                 'IT-PP-15': palette[9],
                 'IT-PP-16': palette[17],
                 'IT-PP-17': palette[21],
                 'IT-PP-18': palette[19],
                 'IT-PP-19': palette[12],
                 'IT-PP-20': palette[18],
                 'LCor': palette[22],
                 'Leir': palette[10],
                 'SiMe': palette[24],
                 'TMJT': palette[5],
                 'Tunisia': palette[26]}

# %%
def plot_pca_coords(coords, model, pc1, pc2, ax, sample_population):
    sns.despine(ax=ax, offset=5)
    x = coords[:, pc1]
    y = coords[:, pc2]
    for pop in populations:
        flt = (sample_population == pop)
        ax.plot(x[flt], y[flt], marker='o', linestyle=' ', color=pop_colours[pop], 
                label=pop, markersize=6, mec='k', mew=.5)
    ax.set_xlabel('PC%s (%.1f%%)' % (pc1+1, model.explained_variance_ratio_[pc1]*100))
    ax.set_ylabel('PC%s (%.1f%%)' % (pc2+1, model.explained_variance_ratio_[pc2]*100))
    
def fig_pca(coords, model, title, sample_population=None):
    if sample_population is None:
        sample_population = samples.Population.values
    # plot coords for PCs 1 vs 2, 3 vs 4
    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(1, 2, 1)
    plot_pca_coords(coords, model, 0, 1, ax, sample_population)
    ax = fig.add_subplot(1, 2, 2)
    plot_pca_coords(coords, model, 2, 3, ax, sample_population)
    ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
    fig.suptitle(title, y=0.97)

# %%
flt = (ac[:, :2].min(axis=1) > 1)
gf = genotypes.compress(flt, axis=0)
gn = gf.to_n_alt()
gn
# Out:
# <ChunkedArrayWrapper shape=(1889864, 599) dtype=int8 chunks=(3692, 599)
#    nbytes=1.1G cbytes=151.2M cratio=7.1
#    compression=blosc compression_opts={'cname': 'lz4', 'clevel': 5, 'shuffle': 1, 'blocksize': 0}
#    values=zarr.core.Array>

# %%
coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-20-3ae3b5cc3eac> in <module>
# ----> 1 coords1, model1 = allel.pca(gn, n_components=10, scaler='patterson')
#
# /wrk/miniconda/envs/pyenvSciKitAllel/lib/python3.6/site-packages/allel/stats/decomposition.py in pca(gn, n_components, copy, scaler, ploidy)
#      56
#      57     # fit the model and project the input data onto the new dimensions
# ---> 58     coords = model.fit_transform(gn)
#      59
#      60     return coords, model
#
# /wrk/miniconda/envs/pyenvSciKitAllel/lib/python3.6/site-packages/allel/stats/decomposition.py in fit_transform(self, gn)
#      75
#      76     def fit_transform(self, gn):
# ---> 77         u, s, v = self._fit(gn)
#      78         u = u[:, :self.n_components]
#      79         u *= s[:self.n_components]
#
# /wrk/miniconda/envs/pyenvSciKitAllel/lib/python3.6/site-packages/allel/stats/decomposition.py in _fit(self, gn)
#      92
#      93         # singular value decomposition
# ---> 94         u, s, v = scipy.linalg.svd(x, full_matrices=False)
#      95
#      96         # calculate explained variance
#
# /wrk/miniconda/envs/pyenvSciKitAllel/lib/python3.6/site-packages/scipy/linalg/decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     127     # perform decomposition
#     128     u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
# --> 129                           full_matrices=full_matrices, overwrite_a=overwrite_a)
#     130
#     131     if info > 0:
#
# MemoryError:

# %%
fig_pca(coords1, model1, 'Figure 1. Conventional PCA.')
